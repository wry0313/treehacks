# %% [markdown]
# We want to use `OpenAIEmbeddings` so we have to get the OpenAI API Key.

# %%
from langchain.docstore.document import Document
from langchain.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.embeddings.fastembed import FastEmbedEmbeddings

from langchain_iris import IRISVector

# %%
import getpass
import os
from dotenv import load_dotenv

load_dotenv(override=True)

# if not os.environ.get("OPENAI_API_KEY"):
#     os.environ["OPENAI_API_KEY"] = getpass.getpass("OpenAI API Key:")

if not os.environ.get("OPENAI_API_KEY"):
    embeddings = FastEmbedEmbeddings()
else:
    embeddings = OpenAIEmbeddings()

# %%
loader = TextLoader("./CS70Notes.txt", encoding='utf-8')

documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=300, chunk_overlap=20)
docs = text_splitter.split_documents(documents)

embeddings = OpenAIEmbeddings()

# mteb
# embeddings = FastEmbedEmbeddings()
# Out:
# Created a chunk of size 588, which is longer than the specified 300
# Created a chunk of size 368, which is longer than the specified 300
# Created a chunk of size 313, which is longer than the specified 300

# %%
username = 'SUPERUSER'
password = 'SYS2' # Replace password with password you set
hostname = 'localhost' 
port = '1972' 
namespace = 'USER'
CONNECTION_STRING = f"iris://{username}:{password}@{hostname}:{port}/{namespace}"

# %%
print(CONNECTION_STRING)
# Out:
# iris://SUPERUSER:SYS2@localhost:1972/USER

# %%
# COLLECTION_NAME = "fadfadafaf"

db = IRISVector.from_documents(
    embedding=embeddings,
    documents=docs,
    collection_name=COLLECTION_NAME,
    connection_string=CONNECTION_STRING,
)

# %%
query = "How do I find a stable matching?"
docs_with_score = db.similarity_search_with_score(query)

# %%
docs_with_score
# Out:
# [(Document(page_content='The Stable Matching Problem is analyzed using proof techniques to find a solution that matches jobs and candidates based on their preferences.\n\nThe Propose-and-Reject algorithm (Gale-Shapley algorithm) is introduced as a simple, fast, and widely-used method to achieve stable matchings.', metadata={'source': './CS70Notes.txt'}),
#   0.145443041425383),
#  (Document(page_content='Stability is defined as a key property, ensuring no job and candidate pair would prefer each other over their current matches.\n\nAnalysis proves the algorithm always halts and produces stable matchings, leveraging the Improvement Lemma and well-ordering principle.', metadata={'source': './CS70Notes.txt'}),
#   0.163789657715167),
#  (Document(page_content='The algorithm operates in discrete time "days," with jobs proposing to candidates and candidates either accepting ("maybe") or rejecting offers until no offers are rejected.\n\nThe algorithm\'s termination results in stable matchings, where no pair would benefit from switching partners.', metadata={'source': './CS70Notes.txt'}),
#   0.168020499261042),
#  (Document(page_content="The concept of optimality is explored, distinguishing between job/employer optimal and candidate optimal matchings, demonstrating the algorithm's job/employer optimality.", metadata={'source': './CS70Notes.txt'}),
#   0.196083442869214)]

# %%
has = set()
all = list()

for doc, score in docs_with_score:
    if doc.page_content in has:
        continue
    
    all.append((doc, score))
    has.add(doc.page_content)
    print("-" * 80)
    print("Score: ", score)
    print(doc.page_content)
    print("-" * 80)
# Out:
# --------------------------------------------------------------------------------
# Score:  0.145443041425383
# The Stable Matching Problem is analyzed using proof techniques to find a solution that matches jobs and candidates based on their preferences.
#
# The Propose-and-Reject algorithm (Gale-Shapley algorithm) is introduced as a simple, fast, and widely-used method to achieve stable matchings.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.163789657715167
# Stability is defined as a key property, ensuring no job and candidate pair would prefer each other over their current matches.
#
# Analysis proves the algorithm always halts and produces stable matchings, leveraging the Improvement Lemma and well-ordering principle.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.168020499261042
# The algorithm operates in discrete time "days," with jobs proposing to candidates and candidates either accepting ("maybe") or rejecting offers until no offers are rejected.
#
# The algorithm's termination results in stable matchings, where no pair would benefit from switching partners.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.196083442869214
# The concept of optimality is explored, distinguishing between job/employer optimal and candidate optimal matchings, demonstrating the algorithm's job/employer optimality.
# --------------------------------------------------------------------------------

# %%
db.add_documents([Document(page_content="random irrevalant stuff")])
docs_with_score = db.similarity_search_with_score("random irrevalant stuff")
docs_with_score[0]
# Out:
# (Document(page_content='random irrevalant stuff'), 0.0)

# %%
retriever = db.as_retriever()
print(retriever)

all_nodes = []
for i in range(30):
    all_nodes.append(docs[i].page_content)
# Out:
# tags=['IRISVector'] vectorstore=<langchain_iris.vectorstores.IRISVector object at 0x14f09d210>

# %%
adjacency_list = {}

def getShort(S):
    return S[0:20] + '...'

def getAdjacentWeightedEdges(query = "How do I find a stable matching?"):
    if query not in adjacency_list:
        adjacency_list[getShort(query)] = []
        
    docs_with_score = db.similarity_search_with_score(query)

    has = set()
    all = list()

    for doc, score in docs_with_score:
        if doc.page_content in has:
            continue
        
        all.append((doc, score))
        has.add(doc.page_content)
        print("-" * 80)
        print("Score: ", score)
        print(doc.page_content)
        print("-" * 80)
        
        
    for i in all:
        # remove self-edges
        if getShort(i[0].page_content) == getShort(query):
            continue
        
        adjacency_list[getShort(query)].append(getShort(i[0].page_content))
        if(getShort(i[0].page_content) not in adjacency_list):
            adjacency_list[getShort(i[0].page_content)] = []
        # print(i[0].page_content[0:10])
        
for i in all_nodes:
    getAdjacentWeightedEdges(i)
    

# for i in
# Out:
# --------------------------------------------------------------------------------
# Score:  0.0
# The Stable Matching Problem is analyzed using proof techniques to find a solution that matches jobs and candidates based on their preferences.
#
# The Propose-and-Reject algorithm (Gale-Shapley algorithm) is introduced as a simple, fast, and widely-used method to achieve stable matchings.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.115901235647094
# Stability is defined as a key property, ensuring no job and candidate pair would prefer each other over their current matches.
#
# Analysis proves the algorithm always halts and produces stable matchings, leveraging the Improvement Lemma and well-ordering principle.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.116045523037894
# The algorithm operates in discrete time "days," with jobs proposing to candidates and candidates either accepting ("maybe") or rejecting offers until no offers are rejected.
#
# The algorithm's termination results in stable matchings, where no pair would benefit from switching partners.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.131356867697027
# The concept of optimality is explored, distinguishing between job/employer optimal and candidate optimal matchings, demonstrating the algorithm's job/employer optimality.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  4.21429406e-06
# The algorithm operates in discrete time "days," with jobs proposing to candidates and candidates either accepting ("maybe") or rejecting offers until no offers are rejected.
#
# The algorithm's termination results in stable matchings, where no pair would benefit from switching partners.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.115859347258535
# The Stable Matching Problem is analyzed using proof techniques to find a solution that matches jobs and candidates based on their preferences.
#
# The Propose-and-Reject algorithm (Gale-Shapley algorithm) is introduced as a simple, fast, and widely-used method to achieve stable matchings.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.127648352484832
# Stability is defined as a key property, ensuring no job and candidate pair would prefer each other over their current matches.
#
# Analysis proves the algorithm always halts and produces stable matchings, leveraging the Improvement Lemma and well-ordering principle.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.137814443142702
# The concept of optimality is explored, distinguishing between job/employer optimal and candidate optimal matchings, demonstrating the algorithm's job/employer optimality.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  8.21012962e-07
# Stability is defined as a key property, ensuring no job and candidate pair would prefer each other over their current matches.
#
# Analysis proves the algorithm always halts and produces stable matchings, leveraging the Improvement Lemma and well-ordering principle.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.115921868009788
# The Stable Matching Problem is analyzed using proof techniques to find a solution that matches jobs and candidates based on their preferences.
#
# The Propose-and-Reject algorithm (Gale-Shapley algorithm) is introduced as a simple, fast, and widely-used method to achieve stable matchings.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.127683579596262
# The algorithm operates in discrete time "days," with jobs proposing to candidates and candidates either accepting ("maybe") or rejecting offers until no offers are rejected.
#
# The algorithm's termination results in stable matchings, where no pair would benefit from switching partners.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.150468388503519
# The concept of optimality is explored, distinguishing between job/employer optimal and candidate optimal matchings, demonstrating the algorithm's job/employer optimality.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.558136378e-06
# The concept of optimality is explored, distinguishing between job/employer optimal and candidate optimal matchings, demonstrating the algorithm's job/employer optimality.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.131468279705858
# The Stable Matching Problem is analyzed using proof techniques to find a solution that matches jobs and candidates based on their preferences.
#
# The Propose-and-Reject algorithm (Gale-Shapley algorithm) is introduced as a simple, fast, and widely-used method to achieve stable matchings.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.138145971154566
# The algorithm operates in discrete time "days," with jobs proposing to candidates and candidates either accepting ("maybe") or rejecting offers until no offers are rejected.
#
# The algorithm's termination results in stable matchings, where no pair would benefit from switching partners.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.15053972730026
# Stability is defined as a key property, ensuring no job and candidate pair would prefer each other over their current matches.
#
# Analysis proves the algorithm always halts and produces stable matchings, leveraging the Improvement Lemma and well-ordering principle.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.120912163e-06
# Historical context is provided, including the use of the algorithm in the Residency Match program for medical graduates and hospitals, highlighting its real-world impact.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.105562572857232
# The note discusses the implications of algorithm design on institutional structures and outcomes, reflecting on power dynamics and institutional changes in the National Residency Matching Program.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.181787205640563
# The concept of optimality is explored, distinguishing between job/employer optimal and candidate optimal matchings, demonstrating the algorithm's job/employer optimality.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.192598490304307
# The Stable Matching Problem is analyzed using proof techniques to find a solution that matches jobs and candidates based on their preferences.
#
# The Propose-and-Reject algorithm (Gale-Shapley algorithm) is introduced as a simple, fast, and widely-used method to achieve stable matchings.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.874825115e-06
# The note discusses the implications of algorithm design on institutional structures and outcomes, reflecting on power dynamics and institutional changes in the National Residency Matching Program.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.1055553527343
# Historical context is provided, including the use of the algorithm in the Residency Match program for medical graduates and hospitals, highlighting its real-world impact.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.162684613118339
# The concept of optimality is explored, distinguishing between job/employer optimal and candidate optimal matchings, demonstrating the algorithm's job/employer optimality.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.16954596802489
# The algorithm operates in discrete time "days," with jobs proposing to candidates and candidates either accepting ("maybe") or rejecting offers until no offers are rejected.
#
# The algorithm's termination results in stable matchings, where no pair would benefit from switching partners.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  2.038178206e-05
# Further reading suggests Gale and Shapley's original paper and a book by Gusfield and Irving for more on the Stable Marriage Problem and its developments
#
# Graph Basics: Introduction of undirected and directed graphs, with vertices and edges representing connections.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.148017558197478
# The Stable Matching Problem is analyzed using proof techniques to find a solution that matches jobs and candidates based on their preferences.
#
# The Propose-and-Reject algorithm (Gale-Shapley algorithm) is introduced as a simple, fast, and widely-used method to achieve stable matchings.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.160032963617081
# RSA's implementation and efficiency in practical applications are also discussed, emphasizing the feasibility of using this system for secure digital communication.
#
# Graph Basics: Introduction of undirected and directed graphs, with vertices and edges representing connections.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.175831351173852
# Hall's Marriage Theorem: A condition that guarantees a perfect matching in bipartite graphs, stating that for every subset of one part, the number of neighbors is at least as large as the subset.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.000574622497487
# Eulerian Tours: Conditions for the existence of a tour that visits each edge exactly once in a graph.
#
# Trees: Characterization of trees as connected, acyclic graphs, and properties such as the number of edges being one less than the number of vertices.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.153673519993625
# Planar Graphs and Euler's Formula: Discussion on planar graphs, Euler's formula relating vertices, edges, and faces, and the concept of graph coloring.
#
# Hypercubes: Exploration of hypercubes as graphs representing n-dimensional cubes, with vertices connected based on differing by one bit.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.780049054e-06
# Planar Graphs and Euler's Formula: Discussion on planar graphs, Euler's formula relating vertices, edges, and faces, and the concept of graph coloring.
#
# Hypercubes: Exploration of hypercubes as graphs representing n-dimensional cubes, with vertices connected based on differing by one bit.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.144802468900251
# Connectivity and Path Finding: Detailed analysis of graph connectivity, including the concept of connected components and the importance of trees and hypercubes for efficient path finding and network design.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.1530495312349
# Eulerian Tours: Conditions for the existence of a tour that visits each edge exactly once in a graph.
#
# Trees: Characterization of trees as connected, acyclic graphs, and properties such as the number of edges being one less than the number of vertices.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.000183528700337
# Connectivity and Path Finding: Detailed analysis of graph connectivity, including the concept of connected components and the importance of trees and hypercubes for efficient path finding and network design.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.025697247512346
# Connectivity and Path Finding: Detailed analysis of graph connectivity, including the concept of connected components and the importance of trees and hypercubes for efficient path finding and network design.
#
# Key Generation:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.143920649789216
# Planar Graphs and Euler's Formula: Discussion on planar graphs, Euler's formula relating vertices, edges, and faces, and the concept of graph coloring.
#
# Hypercubes: Exploration of hypercubes as graphs representing n-dimensional cubes, with vertices connected based on differing by one bit.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.255316007e-06
# RSA cryptography allows secure communication without prior sharing of private keys, using a public/private key pair for encryption and decryption.
#
# It's based on modular arithmetic and the difficulty of factoring large prime numbers, making it secure under current computational capabilities.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.106498000227946
# The security of RSA is dependent on the computational impracticality of factoring large numbers and determining original messages from encrypted ones without the private key.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.109171108753035
# Security: The security of RSA relies on the difficulty of factoring the large number N back into its prime components p and q. Without the knowledge of p and q, an attacker cannot compute the private key d from the public key (N, e). RSA's encryption and decryption work because of the mathematical property that (m^e)^d ≡ m (mod N) for all messages m, assuming m < N.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.127888813208697
# The document outlines the RSA encryption and decryption processes, including generating public and private keys, and encrypting and decrypting messages.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.06377542e-06
# The document outlines the RSA encryption and decryption processes, including generating public and private keys, and encrypting and decrypting messages.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.127786309618989
# RSA cryptography allows secure communication without prior sharing of private keys, using a public/private key pair for encryption and decryption.
#
# It's based on modular arithmetic and the difficulty of factoring large prime numbers, making it secure under current computational capabilities.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.140292939291816
# RSA's implementation and efficiency in practical applications are also discussed, emphasizing the feasibility of using this system for secure digital communication.
#
# Graph Basics: Introduction of undirected and directed graphs, with vertices and edges representing connections.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.141917087846817
# Security: The security of RSA relies on the difficulty of factoring the large number N back into its prime components p and q. Without the knowledge of p and q, an attacker cannot compute the private key d from the public key (N, e). RSA's encryption and decryption work because of the mathematical property that (m^e)^d ≡ m (mod N) for all messages m, assuming m < N.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.792643019e-06
# The security of RSA is dependent on the computational impracticality of factoring large numbers and determining original messages from encrypted ones without the private key.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.087544476970178
# Security: The security of RSA relies on the difficulty of factoring the large number N back into its prime components p and q. Without the knowledge of p and q, an attacker cannot compute the private key d from the public key (N, e). RSA's encryption and decryption work because of the mathematical property that (m^e)^d ≡ m (mod N) for all messages m, assuming m < N.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.1064541120719
# RSA cryptography allows secure communication without prior sharing of private keys, using a public/private key pair for encryption and decryption.
#
# It's based on modular arithmetic and the difficulty of factoring large prime numbers, making it secure under current computational capabilities.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.154270345902809
# The document outlines the RSA encryption and decryption processes, including generating public and private keys, and encrypting and decrypting messages.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.0
# RSA's implementation and efficiency in practical applications are also discussed, emphasizing the feasibility of using this system for secure digital communication.
#
# Graph Basics: Introduction of undirected and directed graphs, with vertices and edges representing connections.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.140315946625176
# The document outlines the RSA encryption and decryption processes, including generating public and private keys, and encrypting and decrypting messages.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.140338319144033
# RSA cryptography allows secure communication without prior sharing of private keys, using a public/private key pair for encryption and decryption.
#
# It's based on modular arithmetic and the difficulty of factoring large prime numbers, making it secure under current computational capabilities.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.160661667349645
# Further reading suggests Gale and Shapley's original paper and a book by Gusfield and Irving for more on the Stable Marriage Problem and its developments
#
# Graph Basics: Introduction of undirected and directed graphs, with vertices and edges representing connections.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.000574622497487
# Eulerian Tours: Conditions for the existence of a tour that visits each edge exactly once in a graph.
#
# Trees: Characterization of trees as connected, acyclic graphs, and properties such as the number of edges being one less than the number of vertices.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.153673519993625
# Planar Graphs and Euler's Formula: Discussion on planar graphs, Euler's formula relating vertices, edges, and faces, and the concept of graph coloring.
#
# Hypercubes: Exploration of hypercubes as graphs representing n-dimensional cubes, with vertices connected based on differing by one bit.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.780049054e-06
# Planar Graphs and Euler's Formula: Discussion on planar graphs, Euler's formula relating vertices, edges, and faces, and the concept of graph coloring.
#
# Hypercubes: Exploration of hypercubes as graphs representing n-dimensional cubes, with vertices connected based on differing by one bit.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.144802468900251
# Connectivity and Path Finding: Detailed analysis of graph connectivity, including the concept of connected components and the importance of trees and hypercubes for efficient path finding and network design.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.1530495312349
# Eulerian Tours: Conditions for the existence of a tour that visits each edge exactly once in a graph.
#
# Trees: Characterization of trees as connected, acyclic graphs, and properties such as the number of edges being one less than the number of vertices.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  2.0934591547e-05
# Connectivity and Path Finding: Detailed analysis of graph connectivity, including the concept of connected components and the importance of trees and hypercubes for efficient path finding and network design.
#
# Key Generation:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.025667165466784
# Connectivity and Path Finding: Detailed analysis of graph connectivity, including the concept of connected components and the importance of trees and hypercubes for efficient path finding and network design.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.159448799900918
# Planar Graphs and Euler's Formula: Discussion on planar graphs, Euler's formula relating vertices, edges, and faces, and the concept of graph coloring.
#
# Hypercubes: Exploration of hypercubes as graphs representing n-dimensional cubes, with vertices connected based on differing by one bit.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  5.417690546e-06
# Choose two large prime numbers p and q. Compute N = pq, which serves as the modulus for both the public and private keys. The size of N dictates the security of the system, with larger values being more secure but also slower to compute. Calculate φ(N) = (p-1)(q-1), which is used in determining the public and private keys. Choose an integer e such that 1 < e < φ(N) and e is coprime to φ(N), making e the public key exponent. Determine d as the modular multiplicative inverse of e modulo φ(N), meaning d is the private key exponent satisfying the equation de ≡ 1 (mod φ(N)).
# Encryption:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.106969836830245
# Security: The security of RSA relies on the difficulty of factoring the large number N back into its prime components p and q. Without the knowledge of p and q, an attacker cannot compute the private key d from the public key (N, e). RSA's encryption and decryption work because of the mathematical property that (m^e)^d ≡ m (mod N) for all messages m, assuming m < N.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.131778764095703
# The sender, Alice, takes the recipient's public key (N, e) and the message M, which has been converted into an integer m in the range 0 < m < N. Alice computes the ciphertext c using the equation c ≡ m^e (mod N).
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.158174279608427
# Decryption: The recipient, Bob, uses his private key d to compute m ≡ c^d (mod N). Since m is the original message, Bob successfully retrieves M from m.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.939937586e-06
# The sender, Alice, takes the recipient's public key (N, e) and the message M, which has been converted into an integer m in the range 0 < m < N. Alice computes the ciphertext c using the equation c ≡ m^e (mod N).
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.08514353365508
# Decryption: The recipient, Bob, uses his private key d to compute m ≡ c^d (mod N). Since m is the original message, Bob successfully retrieves M from m.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.131726084307332
# Choose two large prime numbers p and q. Compute N = pq, which serves as the modulus for both the public and private keys. The size of N dictates the security of the system, with larger values being more secure but also slower to compute. Calculate φ(N) = (p-1)(q-1), which is used in determining the public and private keys. Choose an integer e such that 1 < e < φ(N) and e is coprime to φ(N), making e the public key exponent. Determine d as the modular multiplicative inverse of e modulo φ(N), meaning d is the private key exponent satisfying the equation de ≡ 1 (mod φ(N)).
# Encryption:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.148714238340498
# Security: The security of RSA relies on the difficulty of factoring the large number N back into its prime components p and q. Without the knowledge of p and q, an attacker cannot compute the private key d from the public key (N, e). RSA's encryption and decryption work because of the mathematical property that (m^e)^d ≡ m (mod N) for all messages m, assuming m < N.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.649059009e-06
# Decryption: The recipient, Bob, uses his private key d to compute m ≡ c^d (mod N). Since m is the original message, Bob successfully retrieves M from m.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.085002449589297
# The sender, Alice, takes the recipient's public key (N, e) and the message M, which has been converted into an integer m in the range 0 < m < N. Alice computes the ciphertext c using the equation c ≡ m^e (mod N).
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.155289862598117
# Security: The security of RSA relies on the difficulty of factoring the large number N back into its prime components p and q. Without the knowledge of p and q, an attacker cannot compute the private key d from the public key (N, e). RSA's encryption and decryption work because of the mathematical property that (m^e)^d ≡ m (mod N) for all messages m, assuming m < N.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.157975445532214
# Choose two large prime numbers p and q. Compute N = pq, which serves as the modulus for both the public and private keys. The size of N dictates the security of the system, with larger values being more secure but also slower to compute. Calculate φ(N) = (p-1)(q-1), which is used in determining the public and private keys. Choose an integer e such that 1 < e < φ(N) and e is coprime to φ(N), making e the public key exponent. Determine d as the modular multiplicative inverse of e modulo φ(N), meaning d is the private key exponent satisfying the equation de ≡ 1 (mod φ(N)).
# Encryption:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.329398168e-06
# Security: The security of RSA relies on the difficulty of factoring the large number N back into its prime components p and q. Without the knowledge of p and q, an attacker cannot compute the private key d from the public key (N, e). RSA's encryption and decryption work because of the mathematical property that (m^e)^d ≡ m (mod N) for all messages m, assuming m < N.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.087579680494422
# The security of RSA is dependent on the computational impracticality of factoring large numbers and determining original messages from encrypted ones without the private key.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.107082424930989
# Choose two large prime numbers p and q. Compute N = pq, which serves as the modulus for both the public and private keys. The size of N dictates the security of the system, with larger values being more secure but also slower to compute. Calculate φ(N) = (p-1)(q-1), which is used in determining the public and private keys. Choose an integer e such that 1 < e < φ(N) and e is coprime to φ(N), making e the public key exponent. Determine d as the modular multiplicative inverse of e modulo φ(N), meaning d is the private key exponent satisfying the equation de ≡ 1 (mod φ(N)).
# Encryption:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.109121158635805
# RSA cryptography allows secure communication without prior sharing of private keys, using a public/private key pair for encryption and decryption.
#
# It's based on modular arithmetic and the difficulty of factoring large prime numbers, making it secure under current computational capabilities.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  2.80083043e-06
# Hall's Marriage Theorem: A condition that guarantees a perfect matching in bipartite graphs, stating that for every subset of one part, the number of neighbors is at least as large as the subset.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.108510917279936
# Tutte's Theorem: Generalizes Hall's theorem for non-bipartite graphs, providing conditions under which a graph contains a perfect matching.
#
# König's Theorem: Establishes a relationship between the size of a minimum vertex cover and the size of a maximum matching in bipartite graphs.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.15775371145194
# Hales-Jewett Theorem: A fundamental result in Ramsey theory concerning combinatorial lines in grids, with implications for algebra and game theory.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.169800772414056
# Ramsey's Theorem: States that for any given integers r and s, there exists a minimum integer N such that any graph of order N will contain either a complete subgraph of order r or an independent set of order s.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  4.354675053e-06
# Tutte's Theorem: Generalizes Hall's theorem for non-bipartite graphs, providing conditions under which a graph contains a perfect matching.
#
# König's Theorem: Establishes a relationship between the size of a minimum vertex cover and the size of a maximum matching in bipartite graphs.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.108449229006261
# Hall's Marriage Theorem: A condition that guarantees a perfect matching in bipartite graphs, stating that for every subset of one part, the number of neighbors is at least as large as the subset.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.15689709951011
# Turán's Theorem: Provides a formula for the maximum number of edges in a graph without containing a complete graph of a given size, significant in extremal graph theory.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.165823775133781
# Kuratowski's Theorem: Characterizes planar graphs as those that do not contain a subgraph that is a subdivision of either K5 (the complete graph on five vertices) or K3,3 (the complete bipartite graph on six vertices, three of which connect to each of the other three), foundational in graph drawing and topology.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.738632229e-06
# Dijkstra's Algorithm: A graph search algorithm that solves the shortest path problem for a graph with non-negative edge weights, producing a shortest path tree.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.168945821924628
# Ford-Fulkerson Algorithm: A method to compute the maximum flow in a flow network, illustrating the relationship between maximum flow and minimum cut in a network.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.185963096235227
# Connectivity and Path Finding: Detailed analysis of graph connectivity, including the concept of connected components and the importance of trees and hypercubes for efficient path finding and network design.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.192931896462136
# Eulerian Tours: Conditions for the existence of a tour that visits each edge exactly once in a graph.
#
# Trees: Characterization of trees as connected, acyclic graphs, and properties such as the number of edges being one less than the number of vertices.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.840770089e-06
# Ford-Fulkerson Algorithm: A method to compute the maximum flow in a flow network, illustrating the relationship between maximum flow and minimum cut in a network.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.158217716001324
# Menger's Theorem: Provides a fundamental connection between the maximum number of disjoint paths between two vertices and the minimum number of vertices needed to separate them, crucial for network reliability analysis.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.16890257017553
# Dijkstra's Algorithm: A graph search algorithm that solves the shortest path problem for a graph with non-negative edge weights, producing a shortest path tree.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.189218549540662
# Connectivity and Path Finding: Detailed analysis of graph connectivity, including the concept of connected components and the importance of trees and hypercubes for efficient path finding and network design.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.164285924e-06
# Ramsey's Theorem: States that for any given integers r and s, there exists a minimum integer N such that any graph of order N will contain either a complete subgraph of order r or an independent set of order s.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.152312267629691
# Dilworth's Theorem: In poset theory, states that in any finite partially ordered set, the maximum number of elements in any antichain equals the minimum number of chains in a partition of the set.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.153022503818236
# Hales-Jewett Theorem: A fundamental result in Ramsey theory concerning combinatorial lines in grids, with implications for algebra and game theory.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.161470993284871
# Menger's Theorem: Provides a fundamental connection between the maximum number of disjoint paths between two vertices and the minimum number of vertices needed to separate them, crucial for network reliability analysis.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  2.0725757e-06
# Van der Waerden's Theorem: Focuses on arithmetic progressions, stating that for any given positive integers k and l, there exists a minimum integer N such that any l-coloring of the set {1, 2, ..., N} contains at least one monochromatic arithmetic progression of length k.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.151350994001402
# Lovász Local Lemma: A powerful tool in probabilistic combinatorics for showing the existence of graph colorings and other structures under specific conditions, even when direct construction is difficult.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.170179002772788
# Ramsey's Theorem: States that for any given integers r and s, there exists a minimum integer N such that any graph of order N will contain either a complete subgraph of order r or an independent set of order s.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.181364286172931
# Brouwer's Fixed Point Theorem: States that any continuous function from a compact convex set to itself has at least one fixed point, applicable in game theory, economics, and topology.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  8.72794865e-07
# Block Design Theory: Studies the arrangement of elements into subsets (blocks) such that the arrangement satisfies specific balance and symmetry properties.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.202847655574787
# Dilworth's Theorem: In poset theory, states that in any finite partially ordered set, the maximum number of elements in any antichain equals the minimum number of chains in a partition of the set.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.207407793367955
# Latin Squares and Orthogonal Arrays: Discusses the properties of Latin squares, including their construction and application in statistical experiments to control for two nuisance variables.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.217960032676921
# Hales-Jewett Theorem: A fundamental result in Ramsey theory concerning combinatorial lines in grids, with implications for algebra and game theory.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  2.026811001e-06
# Latin Squares and Orthogonal Arrays: Discusses the properties of Latin squares, including their construction and application in statistical experiments to control for two nuisance variables.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.18939840888767
# Planar Graphs and Euler's Formula: Discussion on planar graphs, Euler's formula relating vertices, edges, and faces, and the concept of graph coloring.
#
# Hypercubes: Exploration of hypercubes as graphs representing n-dimensional cubes, with vertices connected based on differing by one bit.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.193736644188517
# Lovász Local Lemma: A powerful tool in probabilistic combinatorics for showing the existence of graph colorings and other structures under specific conditions, even when direct construction is difficult.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  1.904510255e-06
# Diffie-Hellman Key Exchange: A method allowing two parties to jointly establish a shared secret over an insecure channel, foundational for secure communications.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.156699036100062
# RSA cryptography allows secure communication without prior sharing of private keys, using a public/private key pair for encryption and decryption.
#
# It's based on modular arithmetic and the difficulty of factoring large prime numbers, making it secure under current computational capabilities.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.167233691237017
# Elliptic Curve Cryptography (ECC): Offers a form of public-key cryptography based on the algebraic structure of elliptic curves over finite fields, providing the same level of security with smaller keys compared to traditional methods like RSA.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Score:  0.179888894681619
# Decryption: The recipient, Bob, uses his private key d to compute m ≡ c^d (mod N). Since m is the original message, Bob successfully retrieves M from m.
# --------------------------------------------------------------------------------

# %%
print(adjacency_list)
# Out:
# {'The Stable Matching ...': ['Stability is defined...', 'The algorithm operat...', 'The concept of optim...'], 'Stability is defined...': ['The Stable Matching ...', 'The algorithm operat...', 'The concept of optim...'], 'The algorithm operat...': ['The Stable Matching ...', 'Stability is defined...', 'The concept of optim...'], 'The concept of optim...': ['The Stable Matching ...', 'The algorithm operat...', 'Stability is defined...'], 'Historical context i...': ['The note discusses t...', 'The concept of optim...', 'The Stable Matching ...'], 'The note discusses t...': ['Historical context i...', 'The concept of optim...', 'The algorithm operat...'], 'Further reading sugg...': ['The Stable Matching ...', "RSA's implementation...", "Hall's Marriage Theo..."], "RSA's implementation...": ['The document outline...', 'RSA cryptography all...', 'Further reading sugg...'], "Hall's Marriage Theo...": ["Tutte's Theorem: Gen...", 'Hales-Jewett Theorem...', "Ramsey's Theorem: St..."], 'Eulerian Tours: Cond...': ['Planar Graphs and Eu...'], 'Planar Graphs and Eu...': ['Connectivity and Pat...', 'Eulerian Tours: Cond...'], 'Connectivity and Pat...': ['Planar Graphs and Eu...'], 'RSA cryptography all...': ['The security of RSA ...', 'Security: The securi...', 'The document outline...'], 'The security of RSA ...': ['Security: The securi...', 'RSA cryptography all...', 'The document outline...'], 'Security: The securi...': ['The security of RSA ...', 'Choose two large pri...', 'RSA cryptography all...'], 'The document outline...': ['RSA cryptography all...', "RSA's implementation...", 'Security: The securi...'], 'Choose two large pri...': ['Security: The securi...', 'The sender, Alice, t...', 'Decryption: The reci...'], 'The sender, Alice, t...': ['Decryption: The reci...', 'Choose two large pri...', 'Security: The securi...'], 'Decryption: The reci...': ['The sender, Alice, t...', 'Security: The securi...', 'Choose two large pri...'], "Tutte's Theorem: Gen...": ["Hall's Marriage Theo...", "Turán's Theorem: Pro...", "Kuratowski's Theorem..."], 'Hales-Jewett Theorem...': [], "Ramsey's Theorem: St...": ["Dilworth's Theorem: ...", 'Hales-Jewett Theorem...', "Menger's Theorem: Pr..."], "Turán's Theorem: Pro...": [], "Kuratowski's Theorem...": [], "Dijkstra's Algorithm...": ['Ford-Fulkerson Algor...', 'Connectivity and Pat...', 'Eulerian Tours: Cond...'], 'Ford-Fulkerson Algor...': ["Menger's Theorem: Pr...", "Dijkstra's Algorithm...", 'Connectivity and Pat...'], "Menger's Theorem: Pr...": [], "Dilworth's Theorem: ...": [], "Van der Waerden's Th...": ['Lovász Local Lemma: ...', "Ramsey's Theorem: St...", "Brouwer's Fixed Poin..."], 'Lovász Local Lemma: ...': [], "Brouwer's Fixed Poin...": [], 'Block Design Theory:...': ["Dilworth's Theorem: ...", 'Latin Squares and Or...', 'Hales-Jewett Theorem...'], 'Latin Squares and Or...': ['Planar Graphs and Eu...', 'Lovász Local Lemma: ...'], 'Diffie-Hellman Key E...': ['RSA cryptography all...', 'Elliptic Curve Crypt...', 'Decryption: The reci...'], 'Elliptic Curve Crypt...': []}

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create an undirected graph from the adjacency list
G = nx.Graph()

# Add edges to the graph (nodes are added automatically)
for node, neighbors in adjacency_list.items():
    for neighbor in neighbors:
        G.add_edge(node, neighbor)

pos = nx.spring_layout(G, k=0.5, iterations=20)

# Draw the graph
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='gray', node_size=300, font_size=7)

# Show plot
plt.show()

# %%
# Create an undirected graph
G = nx.Graph()

# Add edges with weights
for node, neighbors in adjacency_list.items():
    for neighbor, weight in neighbors:
        G.add_edge(node, neighbor, weight=weight)

# Use the spring layout
pos = nx.spring_layout(G, k=5, iterations=20)

# Draw the graph
nx.draw(G, pos, with_labels=True, node_color='lightblue', edge_color='gray', node_size=400, font_size=7)

# Draw edge labels with smaller font size
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=7)

# Show plot
plt.show()

# %%
print(adjacency_list)
# Out:
# {'The Stable Matching ...': ['The note discusses t...'], 'The note discusses t...': ['Historical context i...'], 'The algorithm operat...': ['The Stable Matching ...'], 'Stability is defined...': ['The Stable Matching ...'], 'The concept of optim...': ['The Stable Matching ...'], 'Historical context i...': ['The concept of optim...', 'The note discusses t...'], 'Further reading sugg...': ['The note discusses t...', 'Graph Basics: Introd...'], 'Graph Basics: Introd...': [], 'Eulerian Tours: Cond...': [], 'Planar Graphs and Eu...': [], 'Connectivity and Pat...': [], 'RSA cryptography all...': ["It's based on modula...", 'The security of RSA ...'], "It's based on modula...": [], 'The security of RSA ...': ['Security: The securi...'], 'The document outline...': ["It's based on modula...", 'RSA cryptography all...'], 'Security: The securi...': [], "RSA's implementation...": ['Connectivity and Pat...', 'The security of RSA ...']}

# %%
db.add_documents([Document(page_content="foo")])
docs_with_score = db.similarity_search_with_score("foo")
docs_with_score[0]
# Out:
# (Document(page_content='foo'), 0.0)

# %%
docs_with_score
# Out:
# [(Document(page_content='foo'), 0.0),
#  (Document(page_content='random irrevalant stuff'), 0.205244494640908),
#  (Document(page_content='Lovász Local Lemma: A powerful tool in probabilistic combinatorics for showing the existence of graph colorings and other structures under specific conditions, even when direct construction is difficult.', metadata={'source': './CS70Notes.txt'}),
#   0.23755241078898),
#  (Document(page_content='Ford-Fulkerson Algorithm: A method to compute the maximum flow in a flow network, illustrating the relationship between maximum flow and minimum cut in a network.', metadata={'source': './CS70Notes.txt'}),
#   0.238677661049354)]

# %%
retriever = db.as_retriever()
print(retriever)
# Out:
# tags=['IRISVector'] vectorstore=<langchain_iris.vectorstores.IRISVector object at 0x14f09d210>
